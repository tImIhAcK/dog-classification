# %%
import random
import os
import itertools
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import MobileNet, ResNet50, EfficientNetB0
# Out:
# 2024-06-18 18:33:25.117641: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-18 18:33:26.433952: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-18 18:33:29.622274: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-18 18:33:40.361392: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
random.seed(43)
tf.random.set_seed(43)
tf.keras.backend.clear_session()
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'false'

# %%
path = "./Mini_Dog_Breed_Data"
# !ls "./Mini_Dog_Breed_Data"
# Out:
# saint_bernard	    siberian_husky  yorkshire_terrier
# scottish_deerhound  silky_terrier

# %%
def view_image(path, tclass):
    folder = os.path.join(path, tclass)
    random_image = random.sample(os.listdir(folder), 2)
    img = mpimg.imread(folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(tclass)
    plt.axis('off')
    print(f'Image shape: {img.shape}')

# %%
view_image(path, 'saint_bernard')
# Out:
# Image shape: (298, 500, 3)

# %%
view_image(path, 'siberian_husky')
# Out:
# Image shape: (500, 481, 3)

# %%
view_image(path, 'yorkshire_terrier')
# Out:
# Image shape: (375, 500, 3)

# %%
img_generator = ImageDataGenerator(
    rescale=1.0/255,
    validation_split=0.2,
    horizontal_flip=True,
    height_shift_range=0.2,
    width_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    rotation_range=40,
)

train_data = img_generator.flow_from_directory(
    path,
    batch_size=8,
    target_size=(224, 224),
    class_mode="categorical",
    color_mode='rgb',
    shuffle=True,
    seed=23,
    subset='training'
)

val_data = img_generator.flow_from_directory(
    path,
    batch_size=8,
    target_size=(224, 224),
    class_mode="categorical",
    color_mode='rgb',
    shuffle=False,
    seed=23,
    subset='validation'
)
# Out:
# Found 383 images belonging to 5 classes.
# Found 94 images belonging to 5 classes.

# %%
base_model = MobileNet(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

for layer in base_model.layers:
    layer.trainable=False

model = tf.keras.models.Sequential([
    base_model,
    layers.Conv2D(64, kernel_size=(2, 2), activation='relu'),
    layers.Conv2D(32, kernel_size=(2, 2), activation='relu'),
    layers.Flatten(),
    layers.Dense(5, activation='softmax')
])

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    patience=5,
    restore_best_weights=True,
    start_from_epoch=10
)

model.compile(
    loss="categorical_crossentropy",
    optimizer="adam", 
    metrics=['accuracy'])

model_history =model.fit(
    train_data,
    epochs=20,
    validation_data=val_data,
    callbacks=[early_stop])
# Out:
# Epoch 1/20
# /home/timihack/anaconda3/lib/python3.9/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.4186 - loss: 1.6756 - val_accuracy: 0.7447 - val_loss: 0.5573
# Epoch 2/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 89s 1s/step - accuracy: 0.7730 - loss: 0.4860 - val_accuracy: 0.8085 - val_loss: 0.4645
# Epoch 3/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 73s 1s/step - accuracy: 0.8992 - loss: 0.2774 - val_accuracy: 0.8511 - val_loss: 0.3749
# Epoch 4/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 72s 1s/step - accuracy: 0.8413 - loss: 0.3711 - val_accuracy: 0.7979 - val_loss: 0.3644
# Epoch 5/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9143 - loss: 0.1748

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_46902/1407236725.py in <module>
#       2
#       3 plt.subplot(1, 2, 1)
# ----> 4 plt.plot(model_history.history['accuracy'])
#       5 plt.plot(model_history.history['val_accuracy'])
#       6 plt.title('Model accuracy')
#
# NameError: name 'model_history' is not defined
